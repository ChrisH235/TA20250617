# %%
#alles importieren was ich so brauche
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Daten laden
taxi = sns.load_dataset("taxis")

#Datensatz abspeichern
taxi.to_csv("taxis.csv", index=False)

sns.boxplot(y=taxi["total"])
plt.show()
